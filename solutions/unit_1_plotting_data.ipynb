# %% [markdown]
# ## Exercise 1.4.1: Plotting Data

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Given the following data:

# %%
import pandas as pd
X = range(100)
Y = [0.01*n**3 for n in X]
data = pd.DataFrame(zip(X,Y), columns=['Seconds', 'Connections'])

# %% [markdown]
# Check the Bokeh documentation for [scatter plots](https://bokeh.pydata.org/en/1.0.2/docs/reference/plotting.html) and generate a scatter plot representing 'Seconds' in the X axis and 'Connections' in the Y axis:

# %%
p = figure(title='Total Connections', x_axis_label='Seconds', y_axis_label='Connections')
p.scatter(x=data['Seconds'], y=data['Connections'])
show(p)
# Out:
#   <div class="bk-root" id="80e75c8c-6464-4787-9a70-d291297cd973"></div>
